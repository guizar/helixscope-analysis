# %% [markdown]
# ## Batch country analysis
#
# In this notebook we will produce national summary statics from the climatic modelling outputs provided by the Helix consortium. Summary statistics (mean, max, min and standard deviation) will be calculated for every country and variable, and where possible, for every model and model run.

# %%
from netCDF4 import Dataset
import os
import re
import fiona
import rasterio
from rasterio.mask import mask
from rasterio.plot import show
from rasterstats import zonal_stats
import geopandas as gpd
import pandas as pd
import numpy as np
from matplotlib.pyplot import cm
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### FUNCTIONS
# First let's define a few functions to separate the analysis tasks as we iterate through each country polygon/impact layer:
#
# - __ncAttributes:__  this function extracts metadata from gridded climate files. It does so by using a combination of `netCDF4` functions and REGEX commands. The results are returned as a dictionary.
#
# - __zstats:__ This is basically a customisation of the `rasterstats.zonal_stats` function. It’s used to extract summary statistics of interest, returning these values as a dictionary.
#
# - __climateSummaries:__ Integrates the 2 functions above, returning  a dictionary consisting of the concatenation of the above functions
#
# - __emptyDict:__ Returns an empty dictionary where the summary statistics and attribute information will be appended.

# %%
def ncAttributes(filepath):
    """
    Purpose: To extract useful metadata from nc files, such as variable names, model_taxonomies, SWL and so on.
    Process: Most of this information is stored in the files’ global attribute description, we will access them using the netCDF4.ncattrs function. A couple of attributes are also encoded in the file name themselves, these will be extracted using REGEX commands.
    Input:  A string with the file’s path, starting from the data folder
    Output: This will return a dictionary object with: SWL_info, impact_tag, institution, is_multi_model_summary, is_seasonal, model_long_name, model_short_name, model_taxonomy, variable
    """

    # --- extract .nc global attribute data
    #: model_long_name, is_seasonal, is_multi_model_summary, SWL_info, impact_tag, institution
    nc_file = Dataset(filepath, 'r')
    nc_globalatt_dic = {}
    nc_attrs = nc_file.ncattrs()
    for nc_attr in nc_attrs:
        nc_globalatt_dic.update({nc_attr: nc_file.getncattr(nc_attr)})
    
    # convert text to bools where relevant
    nc_globalatt_dic['is_multi_model_summary'] = nc_globalatt_dic['is_multi_model_summary'] in ['true', 'True', 'TRUE']
    nc_globalatt_dic['is_seasonal'] = nc_globalatt_dic['is_seasonal'] in ['true', 'True', 'TRUE']

    # --- extract additonal data from filename
    fname = filepath.split("/")[4]
    variable = filepath.split("/")[3]
    model_taxonomy = re.search('(^.*?)\.',fname, re.IGNORECASE).group(1)
    model_short_name = re.search('(^.*?)-',model_taxonomy, re.IGNORECASE).group(1)
    
    # -- create attribute dictionary
    del nc_globalatt_dic['contact']    
    nc_att_dic = {"model_short_name" : model_short_name, "variable" : variable, "model_taxonomy" : model_taxonomy}
    nc_att_dic.update(nc_globalatt_dic)

    return nc_att_dic

# %%
def zstats(country_shp, rast, zstats_vars,nc_file):
    """
    Purpose: To extract country summaries in a standardised format
    Process: The bulk of this function uses the zonal_stats stats function to perform the calculations. We’re just adding a few pre-defined objects to execute this function in a for loop, as we iterate through each country polygon and climate data file.
    Inputs:  country_shp = a shapefile , rast = a rasterio.read object, zstats_vars = a predefined list of variables ,nc_file = a rasterio.open object
    Output: This will return a dictionary object with: max, mean, min, std
    """

    # get stats
    rast_zstats = zonal_stats(country_shp, rast[0], 
                      stats= zstats_vars,
                      all_touched=True,
                      raster_out=False,
                      affine=nc_file.profile['transform'], 
                      nodata= nc_file.profile.get("nodata"))
    
    # encode in dictionary format
    stats_dic = {"mean" : rast_zstats[0]['mean'], 
                 "max" : rast_zstats[0]['max'],
                 "min" : rast_zstats[0]['min'],
                 "std": rast_zstats[0]['std']}
    
    return stats_dic


# define zonal sats of interest to be uused with the abive function
zstats_vars = ['mean', 'max','min','std']

# %%
def climateSummaries(filepath,country_shp,zstats_vars):
    """
    Purpose: To integrate attribute and summary statistics data extraction within each iteration 
    Inputs:  country_shp = a shapefile , rast = a rasterio.read object, zstats_vars = a predefined list of variables ,nc_file = a rasterio.open object
    Output: This will return a dictionary object that concatenates  the dictionary objects resulting from the ncAttributes and zstats funcions
    """
    # read ncdf
    nc_file = rasterio.open(filepath)
    rast = nc_file.read()

    # get zonal stats
    stats_dic = zstats(country_shp,rast,zstats_vars,nc_file)

    # get nc file attributes
    nc_att_dic = ncAttributes(filepath)

    # -- Build 'data row' (for pandas) ---
    row = stats_dic
    row.update(nc_att_dic)
    return row

# %%
def emptyDict():
    """
    Used to generate an empty dictionary object which will be used to store the values resulting from the summary iterations
    """
    return {
    'country':[],
    'impact_tag':[],
    'variable':[],
    'SWL_info':[],
    'model_short_name':[],
    'max':[],
    'mean':[],
    'min':[],
    'std':[],
    'model_long_name':[],
    'is_seasonal':[],
    'is_multi_model_summary':[],
    'iso2':[],
    'model_taxonomy':[],
    'institution':[]
}

# %% [markdown]
# ### Read data files
#
# Below we will create a list of all available impacts layers (.nc files) and load a global national boundaries shapefile

# %%
# Get .nc filenames and paths
rootdir = "data/Helix/"

# create file paths list
filepaths = []
for (subdir, dirs, files) in os.walk(rootdir):
    for file in files:
        fpath = os.path.join(subdir, file)
        if re.search('.nc$',fpath):
            filepaths.append(fpath)

# %%
# Read countries
countries_shp = gpd.read_file('./data/minified_gadm28_countries/gadm28_countries.shp')

# %% [markdown]
# ### Run batch analysis
#
# For each country polygon and impact layer the process will be to:
#
# 1. Extract the layers' metadata details
# 2. Clip impact layers with the country polygons
# 3. Extract the layers' summary statistics (mean, max, min, std)
# 4. Concatenate all summary outputs in a single dataframe
#
# This is roughgly the same process encoded in the `climateSummaries` function.
#
# __NOTE:__ For testing purposes, the _for loop_ below is running on a subset of the country shapefiles. You need to remove the index subsetting to go through all the countries.  The script will take about 1.5 hrs to generate all the summaries.

# %%
# Define empty DF
data = emptyDict()

# ----  PRODUCE SUMMARIES ---
for i in countries_shp.index.values[239:240]:
        
    # load country shape
    country_shp = countries_shp.iloc[[i]]
    
    # get country_shp attibutes
    country_att_dic = {'iso2' : country_shp.iso2.to_string(index=False),
                       'country' : country_shp.name_engli.to_string(index=False)}

    for filepath in filepaths:
        row = climateSummaries(filepath,country_shp,zstats_vars)
        row.update(country_att_dic)
        
        for var in row:
            data[var].append(row[var])
# Out:
# WARNING:rasterio._gdal:CPLE_AppDefined in No UNIDATA NC_GLOBAL:Conventions attribute

# %% [markdown]
# ### Examine data types and save `.csv` files

# %%
# examine as dataframe 
df = pd.DataFrame(data)
print(df.dtypes)
df
# Out:
# SWL_info                  float64
# country                    object
# impact_tag                 object
# institution                object
# is_multi_model_summary       bool
# is_seasonal                  bool
# iso2                       object
# max                       float64
# mean                      float64
# min                       float64
# model_long_name            object
# model_short_name           object
# model_taxonomy             object
# std                       float64
# variable                   object
# dtype: object
#      SWL_info country impact_tag                            institution  \
# 0         1.5  Zambia        eco                                   LSCE
# 1         2.0  Zambia        eco                                   LSCE
# 2         4.0  Zambia        eco                                   LSCE
# 3         1.5  Zambia        eco                                   LSCE
# 4         2.0  Zambia        eco                                   LSCE
# 5         4.0  Zambia        eco                                   LSCE
# 6         1.5  Zambia        eco                                   LSCE
# 7         2.0  Zambia        eco                                   LSCE
# 8         4.0  Zambia        eco                                   LSCE
# 9         1.5  Zambia        eco                                   LSCE
# 10        2.0  Zambia        eco                                   LSCE
# 11        4.0  Zambia        eco                                   LSCE
# 12        1.5  Zambia        eco                                   LSCE
# 13        2.0  Zambia        eco                                   LSCE
# 14        4.0  Zambia        eco                                   LSCE
# 15        1.5  Zambia        eco                                   LSCE
# 16        2.0  Zambia        eco                                   LSCE
# 17        4.0  Zambia        eco                                   LSCE
# 18        1.5  Zambia        eco                                   LSCE
# 19        2.0  Zambia        eco                                   LSCE
# 20        4.0  Zambia        eco                                   LSCE
# 21        1.5  Zambia        eco                                   LSCE
# 22        2.0  Zambia        eco                                   LSCE
# 23        4.0  Zambia        eco                                   LSCE
# 24        1.5  Zambia        eco                                   LSCE
# 25        2.0  Zambia        eco                                   LSCE
# 26        4.0  Zambia        eco                                   LSCE
# 27        1.5  Zambia        eco                                   LSCE
# 28        2.0  Zambia        eco                                   LSCE
# 29        4.0  Zambia        eco                                   LSCE
# ..        ...     ...        ...                                    ...
# 231       2.0  Zambia         w    Technical University of Crete - TUC
# 232       4.0  Zambia         w    Technical University of Crete - TUC
# 233       1.5  Zambia         w    Technical University of Crete - TUC
# 234       2.0  Zambia         w    Technical University of Crete - TUC
# 235       4.0  Zambia         w    Technical University of Crete - TUC
# 236       1.5  Zambia         w    Technical University of Crete - TUC
# 237       2.0  Zambia         w    Technical University of Crete - TUC
# 238       1.5  Zambia         w    Technical University of Crete - TUC
# 239       2.0  Zambia         w    Technical University of Crete - TUC
# 240       4.0  Zambia         w    Technical University of Crete - TUC
# 241       1.5  Zambia         w    Technical University of Crete - TUC
# 242       2.0  Zambia         w    Technical University of Crete - TUC
# 243       4.0  Zambia         w    Technical University of Crete - TUC
# 244       1.5  Zambia         w    Technical University of Crete - TUC
# 245       2.0  Zambia         w    Technical University of Crete - TUC
# 246       4.0  Zambia         w    Technical University of Crete - TUC
# 247       1.5  Zambia         w    Technical University of Crete - TUC
# 248       2.0  Zambia         w    Technical University of Crete - TUC
# 249       1.5  Zambia         w    Technical University of Crete - TUC
# 250       2.0  Zambia         w    Technical University of Crete - TUC
# 251       4.0  Zambia         w    Technical University of Crete - TUC
# 252       1.5  Zambia         w    Technical University of Crete - TUC
# 253       2.0  Zambia         w    Technical University of Crete - TUC
# 254       4.0  Zambia         w    Technical University of Crete - TUC
# 255       1.5  Zambia         w    Technical University of Crete - TUC
# 256       2.0  Zambia         w    Technical University of Crete - TUC
# 257       4.0  Zambia         w    Technical University of Crete - TUC
# 258       1.5  Zambia         w    Technical University of Crete - TUC
# 259       2.0  Zambia         w    Technical University of Crete - TUC
# 260       4.0  Zambia         w    Technical University of Crete - TUC
#
#     is_multi_model_summary is_seasonal iso2           max          mean  \
# 0                    False       False   ZM  7.317739e+00  3.124083e+00
# 1                    False       False   ZM  7.492836e+00  3.163328e+00
# 2                    False       False   ZM  7.418856e+00  3.325545e+00
# 3                    False       False   ZM  7.332113e+00  2.887211e+00
# 4                    False       False   ZM  6.716383e+00  2.762922e+00
# 5                    False       False   ZM  6.898315e+00  2.771143e+00
# 6                    False       False   ZM  7.277363e+00  2.828334e+00
# 7                    False       False   ZM  7.576070e+00  2.901316e+00
# 8                    False       False   ZM  7.283890e+00  2.834787e+00
# 9                    False       False   ZM  1.464478e+01  4.010631e+00
# 10                   False       False   ZM  1.552142e+01  4.702055e+00
# 11                   False       False   ZM  2.824760e+01  7.435030e+00
# 12                   False       False   ZM  1.667037e+01  3.215970e+00
# 13                   False       False   ZM  1.158007e+01  2.932883e+00
# 14                   False       False   ZM  1.950692e+01  4.245611e+00
# 15                   False       False   ZM  1.409459e+01  2.937221e+00
# 16                   False       False   ZM  1.676355e+01  3.696849e+00
# 17                   False       False   ZM  1.686700e+01  4.513334e+00
# 18                   False       False   ZM  1.496700e+08  7.602725e+07
# 19                   False       False   ZM  1.503726e+08  7.518181e+07
# 20                   False       False   ZM  1.407232e+08  6.826102e+07
# 21                   False       False   ZM  1.586989e+08  7.362895e+07
# 22                   False       False   ZM  1.447762e+08  6.896832e+07
# 23                   False       False   ZM  1.446185e+08  7.170349e+07
# 24                   False       False   ZM  1.456042e+08  6.838357e+07
# 25                   False       False   ZM  1.548160e+08  7.089118e+07
# 26                   False       False   ZM  1.437277e+08  7.059885e+07
# 27                   False       False   ZM  3.409738e+03  1.626547e+03
# 28                   False       False   ZM  3.764717e+03  1.757432e+03
# 29                   False       False   ZM  5.003896e+03  2.204703e+03
# ..                     ...         ...  ...           ...           ...
# 231                  False       False   ZM  5.000000e+00  5.807266e-01
# 232                  False       False   ZM  4.722200e+00 -9.385115e-01
# 233                  False       False   ZM  3.888900e+00  6.418568e-01
# 234                  False       False   ZM  3.333300e+00  2.328295e-01
# 235                  False       False   ZM  4.957300e+00  2.887035e-01
# 236                  False       False   ZM  3.055600e+00 -5.420715e-01
# 237                  False       False   ZM  4.166700e+00  3.532895e-01
# 238                  False       False   ZM  3.055600e+00 -1.860842e-01
# 239                  False       False   ZM  3.888900e+00  8.009712e-01
# 240                  False       False   ZM  4.722200e+00  2.418199e-01
# 241                  False       False   ZM  4.444400e+00 -2.355269e-01
# 242                  False       False   ZM  5.833300e+00  8.269889e-02
# 243                  False       False   ZM  6.686500e+00 -1.426256e+00
# 244                  False       False   ZM  5.000000e+00  9.232288e-01
# 245                  False       False   ZM  5.277800e+00  4.935263e-01
# 246                  False       False   ZM  3.333300e+00 -1.473394e+00
# 247                  False       False   ZM  2.777800e+00 -5.420732e-01
# 248                  False       False   ZM  3.055600e+00 -7.479313e-01
# 249                  False       False   ZM  4.166700e+00 -1.896783e-01
# 250                  False       False   ZM  4.722200e+00 -5.366772e-01
# 251                  False       False   ZM  4.444400e+00 -1.415858e+00
# 252                  False       False   ZM  2.500000e+00 -1.078748e+00
# 253                  False       False   ZM  4.166700e+00 -1.166846e+00
# 254                  False       False   ZM  3.333300e+00 -2.881155e+00
# 255                  False       False   ZM  1.944400e+00 -1.245056e+00
# 256                  False       False   ZM  1.666700e+00 -1.882416e+00
# 257                  False       False   ZM  1.944400e+00 -2.262674e+00
# 258                  False       False   ZM  6.388900e+00  2.597984e-01
# 259                  False       False   ZM  6.388900e+00 -2.283338e-01
# 260                  False       False   ZM  4.444400e+00 -1.451819e+00
#
#               min                                    model_long_name  \
# 0    1.214109e+00                                           ORCHIDEE
# 1    1.196151e+00                                           ORCHIDEE
# 2    1.195607e+00                                           ORCHIDEE
# 3    1.246298e+00                                           ORCHIDEE
# 4    1.195923e+00                                           ORCHIDEE
# 5    1.213085e+00                                           ORCHIDEE
# 6    1.177556e+00                                           ORCHIDEE
# 7    1.179446e+00                                           ORCHIDEE
# 8    1.172966e+00                                           ORCHIDEE
# 9    7.664772e-02                                           ORCHIDEE
# 10   6.926790e-02                                           ORCHIDEE
# 11   1.927176e-02                                           ORCHIDEE
# 12   3.850273e-02                                           ORCHIDEE
# 13   2.645505e-02                                           ORCHIDEE
# 14   5.230294e-02                                           ORCHIDEE
# 15   3.424842e-02                                           ORCHIDEE
# 16   3.733030e-02                                           ORCHIDEE
# 17   3.448053e-02                                           ORCHIDEE
# 18   3.750179e+07                                           ORCHIDEE
# 19   3.669371e+07                                           ORCHIDEE
# 20   2.307083e+07                                           ORCHIDEE
# 21   3.283896e+07                                           ORCHIDEE
# 22   3.113874e+07                                           ORCHIDEE
# 23   3.310070e+07                                           ORCHIDEE
# 24   2.946961e+07                                           ORCHIDEE
# 25   2.989170e+07                                           ORCHIDEE
# 26   2.971462e+07                                           ORCHIDEE
# 27   2.765394e+02                                           ORCHIDEE
# 28   2.579123e+02                                           ORCHIDEE
# 29   8.597610e+01                                           ORCHIDEE
# ..            ...                                                ...
# 231 -9.722200e+00   JULES Joint UK Land Environment Simulator - v...
# 232 -1.722200e+01   JULES Joint UK Land Environment Simulator - v...
# 233 -4.444400e+00   JULES Joint UK Land Environment Simulator - v...
# 234 -4.166700e+00   JULES Joint UK Land Environment Simulator - v...
# 235 -8.782100e+00   JULES Joint UK Land Environment Simulator - v...
# 236 -5.277800e+00   JULES Joint UK Land Environment Simulator - v...
# 237 -1.111100e+01   JULES Joint UK Land Environment Simulator - v...
# 238 -5.000000e+00   JULES Joint UK Land Environment Simulator - v...
# 239 -3.888900e+00   JULES Joint UK Land Environment Simulator - v...
# 240 -8.888900e+00   JULES Joint UK Land Environment Simulator - v...
# 241 -8.055600e+00   JULES Joint UK Land Environment Simulator - v...
# 242 -1.305600e+01   JULES Joint UK Land Environment Simulator - v...
# 243 -2.291700e+01   JULES Joint UK Land Environment Simulator - v...
# 244 -3.611100e+00   JULES Joint UK Land Environment Simulator - v...
# 245 -3.611100e+00   JULES Joint UK Land Environment Simulator - v...
# 246 -8.333300e+00   JULES Joint UK Land Environment Simulator - v...
# 247 -6.388900e+00   JULES Joint UK Land Environment Simulator - v...
# 248 -8.611100e+00   JULES Joint UK Land Environment Simulator - v...
# 249 -5.000000e+00   JULES Joint UK Land Environment Simulator - v...
# 250 -5.555600e+00   JULES Joint UK Land Environment Simulator - v...
# 251 -9.166700e+00   JULES Joint UK Land Environment Simulator - v...
# 252 -5.833300e+00   JULES Joint UK Land Environment Simulator - v...
# 253 -6.666700e+00   JULES Joint UK Land Environment Simulator - v...
# 254 -1.222200e+01   JULES Joint UK Land Environment Simulator - v...
# 255 -6.111100e+00   JULES Joint UK Land Environment Simulator - v...
# 256 -8.055600e+00   JULES Joint UK Land Environment Simulator - v...
# 257 -1.027800e+01   JULES Joint UK Land Environment Simulator - v...
# 258 -3.333300e+00   JULES Joint UK Land Environment Simulator - v...
# 259 -5.000000e+00   JULES Joint UK Land Environment Simulator - v...
# 260 -1.166700e+01   JULES Joint UK Land Environment Simulator - v...
#
#     model_short_name         model_taxonomy           std  \
# 0           orchidee  orchidee-giss-ecearth  1.202108e+00
# 1           orchidee  orchidee-giss-ecearth  1.219213e+00
# 2           orchidee  orchidee-giss-ecearth  1.314536e+00
# 3           orchidee  orchidee-ipsl-ecearth  1.087978e+00
# 4           orchidee  orchidee-ipsl-ecearth  1.030732e+00
# 5           orchidee  orchidee-ipsl-ecearth  1.039807e+00
# 6           orchidee   orchidee-ipsl-hadgem  1.084388e+00
# 7           orchidee   orchidee-ipsl-hadgem  1.138141e+00
# 8           orchidee   orchidee-ipsl-hadgem  1.089372e+00
# 9           orchidee  orchidee-giss-ecearth  2.365695e+00
# 10          orchidee  orchidee-giss-ecearth  2.807249e+00
# 11          orchidee  orchidee-giss-ecearth  5.013188e+00
# 12          orchidee  orchidee-ipsl-ecearth  2.236918e+00
# 13          orchidee  orchidee-ipsl-ecearth  1.904223e+00
# 14          orchidee  orchidee-ipsl-ecearth  2.700465e+00
# 15          orchidee   orchidee-ipsl-hadgem  2.089383e+00
# 16          orchidee   orchidee-ipsl-hadgem  2.688335e+00
# 17          orchidee   orchidee-ipsl-hadgem  3.236950e+00
# 18          orchidee  orchidee-giss-ecearth  1.829025e+07
# 19          orchidee  orchidee-giss-ecearth  1.806909e+07
# 20          orchidee  orchidee-giss-ecearth  2.077597e+07
# 21          orchidee  orchidee-ipsl-ecearth  2.010250e+07
# 22          orchidee  orchidee-ipsl-ecearth  1.715799e+07
# 23          orchidee  orchidee-ipsl-ecearth  1.742301e+07
# 24          orchidee   orchidee-ipsl-hadgem  1.781145e+07
# 25          orchidee   orchidee-ipsl-hadgem  2.004538e+07
# 26          orchidee   orchidee-ipsl-hadgem  1.925744e+07
# 27          orchidee  orchidee-giss-ecearth  5.860714e+02
# 28          orchidee  orchidee-giss-ecearth  6.683347e+02
# 29          orchidee  orchidee-giss-ecearth  1.065204e+03
# ..               ...                    ...           ...
# 231            jules      jules-EC-EARTH-r3  1.711130e+00
# 232            jules      jules-EC-EARTH-r3  2.835726e+00
# 233            jules      jules-EC-EARTH-r4  1.549599e+00
# 234            jules      jules-EC-EARTH-r4  1.428500e+00
# 235            jules      jules-EC-EARTH-r4  2.424003e+00
# 236            jules      jules-EC-EARTH-r5  1.297927e+00
# 237            jules      jules-EC-EARTH-r5  2.144047e+00
# 238            jules      jules-EC-EARTH-r6  1.402428e+00
# 239            jules      jules-EC-EARTH-r6  1.319442e+00
# 240            jules      jules-EC-EARTH-r6  1.625467e+00
# 241            jules      jules-EC-EARTH-r7  2.251683e+00
# 242            jules      jules-EC-EARTH-r7  3.134053e+00
# 243            jules      jules-EC-EARTH-r7  5.166011e+00
# 244            jules        jules-HadGEM-r1  1.630435e+00
# 245            jules        jules-HadGEM-r1  1.459084e+00
# 246            jules        jules-HadGEM-r1  2.181705e+00
# 247            jules        jules-HadGEM-r2  1.631407e+00
# 248            jules        jules-HadGEM-r2  2.112527e+00
# 249            jules        jules-HadGEM-r3  1.109415e+00
# 250            jules        jules-HadGEM-r3  1.229689e+00
# 251            jules        jules-HadGEM-r3  2.414748e+00
# 252            jules        jules-HadGEM-r6  1.391653e+00
# 253            jules        jules-HadGEM-r6  1.353981e+00
# 254            jules        jules-HadGEM-r6  2.443785e+00
# 255            jules        jules-HadGEM-r8  1.403745e+00
# 256            jules        jules-HadGEM-r8  1.788490e+00
# 257            jules        jules-HadGEM-r8  2.532029e+00
# 258            jules        jules-HadGEM-r9  1.303918e+00
# 259            jules        jules-HadGEM-r9  1.461957e+00
# 260            jules        jules-HadGEM-r9  2.303460e+00
#
#                   variable
# 0                    cSoil
# 1                    cSoil
# 2                    cSoil
# 3                    cSoil
# 4                    cSoil
# 5                    cSoil
# 6                    cSoil
# 7                    cSoil
# 8                    cSoil
# 9                     cVeg
# 10                    cVeg
# 11                    cVeg
# 12                    cVeg
# 13                    cVeg
# 14                    cVeg
# 15                    cVeg
# 16                    cVeg
# 17                    cVeg
# 18                    evap
# 19                    evap
# 20                    evap
# 21                    evap
# 22                    evap
# 23                    evap
# 24                    evap
# 25                    evap
# 26                    evap
# 27                     gpp
# 28                     gpp
# 29                     gpp
# ..                     ...
# 231  time_perc_change_SRI6
# 232  time_perc_change_SRI6
# 233  time_perc_change_SRI6
# 234  time_perc_change_SRI6
# 235  time_perc_change_SRI6
# 236  time_perc_change_SRI6
# 237  time_perc_change_SRI6
# 238  time_perc_change_SRI6
# 239  time_perc_change_SRI6
# 240  time_perc_change_SRI6
# 241  time_perc_change_SRI6
# 242  time_perc_change_SRI6
# 243  time_perc_change_SRI6
# 244  time_perc_change_SRI6
# 245  time_perc_change_SRI6
# 246  time_perc_change_SRI6
# 247  time_perc_change_SRI6
# 248  time_perc_change_SRI6
# 249  time_perc_change_SRI6
# 250  time_perc_change_SRI6
# 251  time_perc_change_SRI6
# 252  time_perc_change_SRI6
# 253  time_perc_change_SRI6
# 254  time_perc_change_SRI6
# 255  time_perc_change_SRI6
# 256  time_perc_change_SRI6
# 257  time_perc_change_SRI6
# 258  time_perc_change_SRI6
# 259  time_perc_change_SRI6
# 260  time_perc_change_SRI6
#
# [261 rows x 15 columns]

# %%
# Save to CSV
df.to_csv("data/test.csv",index=False,na_rep='')
